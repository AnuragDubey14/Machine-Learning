# %%
import pandas as pd
import requests

# %%
import requests
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=&language=en-US&page=1')

# %%
df=pd.DataFrame(response.json()['results'])

# %%
df=pd.DataFrame()

# %%
for i in range(1,429):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=4d2ea7e8e676ed9e01ce2d84fca43ae2&language=en-US&page={i}')
    temp_df=pd.DataFrame(response.json()['results'])
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#       adult                     backdrop_path         genre_ids      id  \
# 0     False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]     278
# 1     False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg          [18, 80]     238
# 2     False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3     False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4     False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg              [18]     389
# ...     ...                               ...               ...     ...
# 8555  False  /f3ugXLa0w4x3cVVNodBPB6HDmSk.jpg      [28, 12, 53]   10538
# 8556  False  /AbFWty0o5nKGo4iLJaGRgqFtC8W.jpg        [27, 9648]    4234
# 8557  False  /AhwEkJY1RRna8M0dcSAhR9aCeF4.jpg          [53, 27]  459928
# 8558  False  /ww1eIoywghjoMzRLRIcbJLuKnJH.jpg  [28, 53, 18, 80]  343611
# 8559  False  /dGXcMVcWbpMRxo809nO4HNeDluA.jpg              [35]   26691
#
#                             title original_language  \
# ...
